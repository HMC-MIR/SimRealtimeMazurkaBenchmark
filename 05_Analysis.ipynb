# %%
import numpy as np
import pickle
from eval_tools import getGroundTruthTimestamps
import plotly.graph_objs as go

# %%
from OnlineAlignment.core.alignment import run_offline_oltw
f1_path = "/home/ctang/ttmp/SimRealtimeBenchmark/features/chroma_stft/Chopin_Op017No4_Chiu-1999_pid9048-13.npy"
f2_path = "/home/ctang/ttmp/SimRealtimeBenchmark/features/chroma_stft/Chopin_Op017No4_Kiepura-1999_pid9098-20.npy"
f1 = np.load(f1_path)
f2 = np.load(f2_path)

oltw_hyp = run_offline_oltw(f1, f2, c = 500, cost_metric = "cosine")

# %%
# plot oltw_hyp
import matplotlib.pyplot as plt
plt.plot(oltw_hyp[0], oltw_hyp[1])
plt.show()

# %%
# plot oltw_hyp
import matplotlib.pyplot as plt
plt.plot(oltw_hyp[0], oltw_hyp[1])
plt.show()

# %% [markdown]
# # Plot Alignments

# %%
s = 42
match_hyp_file = f"experiments/MATCH/s{s}/hyp.npy"
dtw_hyp_file = f"experiments_match/DTW/s{s}/hyp.npy"
oltw_hyp_file = f"experiments/OLTW/s{s}/hyp.npy"
noa_hyp_file = f"experiments/NOA/s{s}/hyp.npy"
oltw_global_hyp_file = f"experiments_match/OLTW_GLOBAL/s{s}/hyp.npy"

# load the hyp and tsm files
dtw_hyp = np.load(dtw_hyp_file)
oltw_hyp = np.load(oltw_hyp_file)
match_hyp = np.load(match_hyp_file)
noa_hyp = np.load(noa_hyp_file)
oltw_global_hyp = np.load(oltw_global_hyp_file)

# load the ground truth timestamps
query_annot_file = f'scenarios/s{s}/query.beats'
ref_annot_file = f'scenarios/s{s}/ref.beats'
gt = getGroundTruthTimestamps(query_annot_file, ref_annot_file).T

# %%
# Create a figure
fig = go.Figure()
fig.update_layout(
    title='Alignment and TSM Paths',
    xaxis_title='Query Time (s)',
    yaxis_title='Reference Time (s)',
    width=900,
    height=700
)
fig.add_trace(go.Scatter(
    x=match_hyp[0], y=match_hyp[1], mode='lines', name='MATCH Hyp'
))
fig.add_trace(go.Scatter(
    x=dtw_hyp[0], y=dtw_hyp[1], mode='lines', name='DTW Hyp'
))
fig.add_trace(go.Scatter(
    x=oltw_hyp[0], y=oltw_hyp[1], mode='lines', name='OLTW Hyp'
))
fig.add_trace(go.Scatter(
    x=noa_hyp[0], y=noa_hyp[1], mode='lines', name='NOA Hyp'
))
fig.add_trace(go.Scatter(
    x=oltw_hyp[0], y=oltw_hyp[1], mode='lines', name='OLTW Hyp'
))
fig.add_trace(go.Scatter(
    x=gt[0], y=gt[1], mode='markers', name='Ground Truth'
))
fig.add_trace(go.Scatter(
    x=oltw_global_hyp[0], y=oltw_global_hyp[1], mode='lines', name='OLTW Global Hyp'
))
fig.show()

# %% [markdown]
# # Plot Errors

# %%
s = 8

match_eval_file = "eval/MATCH/errs.pkl"
match_tsm_eval_file = "eval_tsm/MATCH/lag0/errs.pkl"
oltw_eval_file = "eval/OLTW/errs.pkl"
oltw_tsm_eval_file = "eval_tsm/OLTW/lag0/errs.pkl"
noa_eval_file = "eval/NOA/errs.pkl"
noa_tsm_eval_files = [f"eval_tsm/NOA/lag{i}/errs.pkl" for i in range(0, 600, 100)]
dtw_eval_file = "eval/DTW/errs.pkl"
dtw_tsm_eval_file = "eval_tsm/DTW/lag0/errs.pkl"
dtw_tsm_lag_400_eval_file = "eval_tsm/DTW/lag400/errs.pkl"
kalman_eval_file = "eval/KALMAN/errs.pkl"
kalman_tsm_eval_file = "eval_tsm/KALMAN/lag0/errs.pkl"

match_err = pickle.load(open(match_eval_file, 'rb'))[f's{s}']
match_tsm_err = pickle.load(open(match_tsm_eval_file, 'rb'))[f's{s}']
oltw_err = pickle.load(open(oltw_eval_file, 'rb'))[f's{s}']
oltw_tsm_err = pickle.load(open(oltw_tsm_eval_file, 'rb'))[f's{s}']
noa_err = pickle.load(open(noa_eval_file, 'rb'))[f's{s}']
noa_tsm_errs = [pickle.load(open(f, 'rb'))[f's{s}'] for f in noa_tsm_eval_files]
dtw_err = pickle.load(open(dtw_eval_file, 'rb'))[f's{s}']
dtw_tsm_err = pickle.load(open(dtw_tsm_eval_file, 'rb'))[f's{s}']
kalman_err = pickle.load(open(kalman_eval_file, 'rb'))[f's{s}']
kalman_tsm_err = pickle.load(open(kalman_tsm_eval_file, 'rb'))[f's{s}']
dtw_tsm_lag_400_err = pickle.load(open(dtw_tsm_lag_400_eval_file, 'rb'))[f's{s}']

# %%
# plot the errors
fig = go.Figure()
fig.update_layout(
    title='Alignment and TSM Errors',
    xaxis_title='Reference Time (s)',
    yaxis_title='Error (s)'
)
fig.add_trace(go.Scatter(x=np.arange(len(dtw_err)), y=dtw_err, mode='lines', name='DTW'))
fig.add_trace(go.Scatter(x=np.arange(len(noa_err)), y=noa_err, mode='lines', name='NOA'))
fig.show()

# %%
s = 12
noa_tsm_eval_files = [f"eval_tsm/NOA/lag{i}/errs.pkl" for i in range(0, 600, 100)]
noa_tsm_errs = [pickle.load(open(f, 'rb'))[f's{s}'] for f in noa_tsm_eval_files]

fig = go.Figure()
fig.update_layout(
    title='Alignment and TSM Errors',
    xaxis_title='Reference Time (s)',
    yaxis_title='Error (s)'
)
i = 0
fig.add_trace(go.Scatter(x=np.arange(len(noa_tsm_errs[i])), y=noa_tsm_errs[i], mode='lines', name=f'NOA TSM Lag {i*100}'))
i = 5
fig.add_trace(go.Scatter(x=np.arange(len(noa_tsm_errs[i])), y=noa_tsm_errs[i], mode='lines', name=f'NOA TSM Lag {i*100}'))
fig.show()

# %% [markdown]
# # Generate Offline Sonifications

# %%
from hmc_mir import tsm_tools
import soundfile as sf
import librosa as lb
def generate_offline_sonification(y, alignment, sr, outfile = None):
    y_mod = tsm_tools.tsmvar_hybrid(y, alignment, sr)
    if outfile:
        sf.write(outfile, y_mod, sr, subtype='PCM_16')
    return y_mod

# %%
s = 15
noa_hyp_file = f"experiments/MATCH/s{s}/hyp.npy"
noa_tsm_file = f"experiments/MATCH/s{s}/tsm.npy"
outfile = "output.wav"

# find the audio id corresponding to scenario s
pair_file = f"scenarios/s{s}/pair.txt"
with open(pair_file, 'r') as f:
    pair = f.read().strip().split()
piece_id1 = pair[0]
piece_id2 = pair[1]

# load audio files
audio_dir = "Chopin_Mazurkas/wav_22050_mono/Chopin_Op017No4/"
y1 = lb.load(audio_dir + piece_id1 + ".wav", sr = 22050)[0]
y2 = lb.load(audio_dir + piece_id2 + ".wav", sr = 22050)[0]

# %%
# generate sonifications
y1_mod = generate_offline_sonification(y1, noa_hyp, 22050, outfile = "output.wav")

# %%
y1_mod_tsm = generate_offline_sonification(y1, noa_tsm, 22050, outfile = "output_tsm.wav")

# %%
import numpy as np

# Ensure both signals are the same length
min_len = min(len(y1_mod), len(y2))
y1_mod_trim = y1_mod[:min_len]
y2_trim = y2[:min_len]

# Stack to stereo (channel 0: y1_mod_tsm, channel 1: y2)
# left channel: y1_mod_tsm, right channel: y2
stereo_audio = np.stack((y1_mod_trim, y2_trim), axis=-1)

# Save as output_overlay.wav
sf.write("output_overlay.wav", stereo_audio, 22050, subtype='PCM_16')

# %%
import numpy as np

# Ensure both signals are the same length
min_len = min(len(y1_mod_tsm), len(y2))
y1_mod_tsm_trim = y1_mod_tsm[:min_len]
y2_trim = y2[:min_len]

# Stack to stereo (channel 0: y1_mod_tsm, channel 1: y2)
# left channel: y1_mod_tsm, right channel: y2
stereo_audio = np.stack((y1_mod_tsm_trim, y2_trim), axis=-1)

# Save as output_overlay.wav
sf.write("output_overlay_tsm.wav", stereo_audio, 22050, subtype='PCM_16')
