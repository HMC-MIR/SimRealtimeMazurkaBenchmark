# %%
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
# Training Losses (25 epochs)
train_losses = np.array([
    3.6393, 3.5206, 3.4876, 3.4689, 3.454, 3.4433, 3.4367, 3.4288, 
    3.4268, 3.4194, 3.4156, 3.4112, 3.4071, 3.4046, 3.3997, 3.3986, 
    3.3953, 3.3947, 3.3938, 3.3891, 3.3896, 3.3876, 3.386, 3.3867, 3.3823
])

# Test Losses (25 epochs)
test_losses = np.array([
    3.51, 3.4801, 3.4721, 3.4599, 3.4544, 3.4502, 3.4598, 3.447, 
    3.4456, 3.4517, 3.4561, 3.4484, 3.4414, 3.4483, 3.4411, 3.4533, 
    3.4568, 3.448, 3.4586, 3.4439, 3.4519, 3.4477, 3.4579, 3.4569, 3.4735
])
# Plotting the training and test losses
plt.figure(figsize=(10, 6))
plt.plot(train_losses, label='Training Loss', marker='o')
plt.plot(test_losses, label='Validation Loss', marker='o')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Loss')
# plt.title('Training and Test Losses over Epochs')
# Out:
# Text(0, 0.5, 'Loss')

# %%
import numpy as np
import matplotlib.pyplot as plt

# Training losses for 44 epochs
train_losses = np.array([
    3.8359, 3.6775, 3.6348, 3.6095, 3.5965, 3.5853, 3.5771, 3.5697,
    3.5652, 3.5589, 3.5567, 3.5526, 3.5491, 3.5472, 3.5441, 3.5412,
    3.5403, 3.5368, 3.5366, 3.5341, 3.5342, 3.5323, 3.5319, 3.5305,
    3.5294, 3.5290, 3.5298, 3.5264, 3.5287, 3.5264, 3.5263, 3.5253,
    3.5233, 3.5230, 3.5243, 3.5243, 3.5234, 3.5232, 3.5227, 3.5225,
    3.5249, 3.5227, 3.5223, 3.5246
])

# Test (Validation) losses for 44 epochs
test_losses = np.array([
    3.6826, 3.6244, 3.5678, 3.5495, 3.5568, 3.5373, 3.5301, 3.5222,
    3.5205, 3.5136, 3.5108, 3.5283, 3.5121, 3.5178, 3.5147, 3.5157,
    3.5153, 3.5098, 3.5092, 3.5060, 3.5212, 3.5137, 3.5131, 3.5061,
    3.5125, 3.5215, 3.5029, 3.5122, 3.5025, 3.5060, 3.5096, 3.5103,
    3.5007, 3.5004, 3.5022, 3.5112, 3.5135, 3.5191, 3.5212, 3.5099,
    3.5070, 3.5019, 3.5119, 3.5005
])

# Plotting the training and test losses
plt.figure(figsize=(10, 6))
plt.plot(train_losses, label='Training Loss', marker='o')
plt.plot(test_losses, label='Validation Loss', marker='o')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

# %%
import numpy as np

# Training losses for 42 epochs
train_losses = np.array([
    3.8324, 3.6778, 3.6335, 3.6098, 3.5946, 3.5822, 3.5754, 3.567, 
    3.5625, 3.5556, 3.5521, 3.551, 3.5467, 3.5456, 3.5408, 3.5398, 
    3.5363, 3.5375, 3.5355, 3.5351, 3.5332, 3.5317, 3.5313, 3.5292, 
    3.5294, 3.5265, 3.5254, 3.5251, 3.5248, 3.5266, 3.524, 3.5246, 
    3.5236, 3.522, 3.5231, 3.5214, 3.5225, 3.5206, 3.5247, 3.5212, 
    3.5222, 3.524
])

# Test (Validation) losses for 42 epochs
test_losses = np.array([
    3.6686, 3.6027, 3.5707, 3.5497, 3.5445, 3.5315, 3.5357, 3.5252, 
    3.5105, 3.5148, 3.5239, 3.5151, 3.5074, 3.5075, 3.5034, 3.5079, 
    3.5217, 3.5052, 3.5062, 3.5119, 3.5135, 3.4971, 3.5129, 3.5038, 
    3.5073, 3.5139, 3.5076, 3.5034, 3.5166, 3.5078, 3.515, 3.5259, 
    3.5139, 3.5158, 3.5078, 3.5011, 3.5167, 3.5174, 3.507, 3.5103, 
    3.5052, 3.5101
])

# Plotting the training and test losses
plt.figure(figsize=(10, 6))
plt.plot(train_losses, label='Training Loss', marker='o')
plt.plot(test_losses, label='Validation', marker='o')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

# %%
import pickle
from pathlib import Path

import eval_tools

def parse_test_scenarios(split_file="noa_nn/train_test_split.txt"):
    scenarios = []
    in_test = False
    with open(split_file, "r", encoding="utf-8") as f:
        for raw in f:
            line = raw.strip()
            if not line or line.startswith("#"):
                continue
            if line.startswith("[") and line.endswith("]"):
                in_test = (line == "[TEST_SCENARIOS]")
                continue
            if in_test:
                scenarios.append(line)
    return scenarios

exp_dir = Path("experiments/NOA_NN")
scenarios_dir = Path("scenarios")
out_dir = Path("eval/NOA_NN")
out_dir.mkdir(parents=True, exist_ok=True)

scenario_ids = parse_test_scenarios("noa_nn/train_test_split_model1.txt")

errs_dict = {}
skipped = []

for sid in scenario_ids:
    hypfile = exp_dir / sid / "hyp.npy"
    q_annot = scenarios_dir / sid / "query.beats"
    r_annot = scenarios_dir / sid / "ref.beats"

    if not hypfile.exists():
        skipped.append((sid, "missing_hyp"))
        continue

    err = eval_tools.eval_alignment_single(str(hypfile), str(q_annot), str(r_annot))

    # Guard against malformed returns
    if err is None or (isinstance(err, tuple) and any(x is None for x in err)):
        skipped.append((sid, "invalid_err"))
        continue

    err = np.asarray(err, dtype=float).reshape(-1)
    err = err[~np.isnan(err)]
    if err.size == 0:
        skipped.append((sid, "empty_err"))
        continue

    errs_dict[sid] = err

with open(out_dir / "errs.pkl", "wb") as f:
    pickle.dump(errs_dict, f)

print(f"Saved: {out_dir / 'errs.pkl'}")
print(f"Evaluated scenarios: {len(errs_dict)}")
print(f"Skipped scenarios: {len(skipped)}")
if skipped:
    print("Skipped detail:", skipped[:10])
# Out:
# Saved: eval/NOA_NN/errs.pkl
# Evaluated scenarios: 18
# Skipped scenarios: 0

# %%
from eval_tools import getGroundTruthTimestamps

noa_nn_path = "experiments/NOA_NN/s6/hyp.npy"
noa_nn_hyp = np.load(noa_nn_path)
dtw_path = "experiments/DTW/s6/hyp.npy"
dtw_hyp = np.load(dtw_path)

s = 6
# load the ground truth timestamps
query_annot_file = f'scenarios/s{s}/query.beats'
ref_annot_file = f'scenarios/s{s}/ref.beats'
gt = getGroundTruthTimestamps(query_annot_file, ref_annot_file).T

import plotly.graph_objs as go

# Create a figure
fig = go.Figure()
fig.update_layout(
    title='Alignment Paths',
    xaxis_title='Query Time (s)',
    yaxis_title='Reference Time (s)',
    width=900,
    height=700
)
fig.add_trace(go.Scatter(
    x=noa_nn_hyp[0], y=noa_nn_hyp[1], mode='lines', name='NOA NN Hyp'
))
fig.add_trace(go.Scatter(
    x=dtw_hyp[0], y=dtw_hyp[1], mode='lines', name='DTW Hyp'
))
fig.add_trace(go.Scatter(
    x=gt[0], y=gt[1], mode='markers', name='Ground Truth'
))
